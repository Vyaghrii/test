# %%
# %pip install osmnx[all]

# %%
import os
import osmnx as ox

# %%
# Define place name and output directory
place_name = "Delhi, India"
output_dir = r"C:\pythonlearning"

# %%
# Create folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# %%
# Download the driveable road network from OpenStreetMap
print(f"Downloading road network for {place_name}...")
G = ox.graph_from_place(place_name, network_type="drive")
# Out:
# Downloading road network for Delhi, India...

# %%
# Convert the graph to GeoDataFrames (nodes and edges)
nodes, edges = ox.graph_to_gdfs(G)

# %%
# Export shapefiles
print("Saving shapefiles...")
nodes.to_file(os.path.join(output_dir, "nodes.shp"))
edges.to_file(os.path.join(output_dir, "edges.shp"))
# Out:
# Saving shapefiles...
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2456\2730349200.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   nodes.to_file(os.path.join(output_dir, "nodes.shp"))
# c:\Users\ASUS\venvs\ml\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'street_count' to 'street_cou'
#   ogr_write(

# %%
print("✅ Export completed successfully!")
print(f"Files saved in: {output_dir}")
# Out:
# ✅ Export completed successfully!
# Files saved in: C:\pythonlearning

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
